# %%
from SBD import kernel_factory, Y_factory

import matplotlib.pyplot as plt

# %%
a = kernel_factory(1, 10, 10)
plt.matshow(a[0])
plt.show()

# %%
Y, A, X = Y_factory(1,(200,200), (10,10), 0.01, 0.9)

# %%
X= X.toarray()
plt.matshow(X)

# %%
plt.matshow(Y[0])
